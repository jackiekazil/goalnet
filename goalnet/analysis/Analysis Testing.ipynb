# %%
from analysis_functions import *
import matplotlib.pyplot as plt

# %%
#PATH = "../outputs/eced2320-564a-474d-bb1d-3dcfcfcf31f4/"
PATH = "../outputs/3ae6c04b-35eb-4744-90b9-4b00724a3b29/"

# %%
data = load_data(PATH+"data.json")

# %%
keys, active_tasks, complete_tasks = count_tasks(data)

# %%
plt.plot(keys, active_tasks, keys, complete_tasks)

# %%
plt.plot(keys, get_ginis(data))

# %%
get_ginis(data)
# Out:
# [0,
#  0,
#  0.97,
#  0.9600490581479539,
#  0.9004763196163947,
#  0.8819360822753,
#  0.8617159306806146,
#  0.83513365480932,
#  0.766029804772705,
#  0.7192643603261171,
#  0.6945764074004666,
#  0.6904870517721127,
#  0.6542277392645117,
#  0.6506714367018838,
#  0.6198891463315745,
#  0.6008960659779004,
#  0.6024052699792624,
#  0.5899435382248048,
#  0.5667580480591694,
#  0.5711354906406074,
#  0.5354431368434107,
#  0.5194919884619984,
#  0.5215149106416133,
#  0.5188149910966049,
#  0.5158875088472314,
#  0.5016887996022452,
#  0.49805758777349274,
#  0.4826947133257793,
#  0.49442465670700364,
#  0.47537890143064354,
#  0.4704559999145037,
#  0.46843056716704723,
#  0.46843056716704723,
#  0.4676696738008179,
#  0.4654999086331473,
#  0.4586318692107494,
#  0.45396758333355214,
#  0.4502187701457798,
#  0.4503852120849914,
#  0.4394142299117474,
#  0.4409170116875418,
#  0.43803612421502125,
#  0.43625526787526203,
#  0.40940444001116005,
#  0.40681648436688134,
# ...
