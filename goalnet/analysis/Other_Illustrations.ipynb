# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.rand(1000000)
dt = -np.log(x)
fig, ax = plt.subplots()
hist = ax.hist(dt, bins=np.linspace(0,10,100), weights=np.zeros_like(dt) + 1.0/dt.size)
ax.set_xlim(0,10)
ax.set_title("PDF")
ax.set_xlabel("$x$")
ax.set_ylabel("$P(\Delta t=x)$")
mean_line = axvline(dt.mean(), color='r')

# %%
hist[0][0]
# Out:
# 0.9389458110477914

# %%
x = np.linspace(0.0001,1,100)
t = -np.log(x)
t /= t.sum()
plt.plot(np.linspace(0,10,100),t)
plt.axvline(1, color='r')
plt.legend(["PDF", "Mean"])

# %%
t.max()
# Out:
# 0.087757879892620363
